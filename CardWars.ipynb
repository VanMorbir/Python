# %%
##global defs
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':11,
         'Queen':12, 'King':13, 'Ace':14}
cards_for_war = 5

# %%
class Card:
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
class Deck:
    def __init__(self):
        self.all_cards = []
        for suit in suits:
            for rank in ranks:
                new_card = Card(suit,rank)
                self.all_cards.append(new_card)
    
    def shuffle(self):
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        return self.all_cards.pop()

# %%
class Player:
    def __init__(self,name):
        self.name = name
        self.hand = []
        
    def remove_one(self):
        return self.hand.pop(0)
    
    def add_card(self,cards):
        if type(cards) == type([]):
            self.hand.extend(cards)
        else:
            self.hand.append(cards)
    
    def __str__(self):
        return f'Player {self.name} has {len(self.hand)} cards'

# %%
#Game Logic
player1 = Player("One")
player2 = Player("Two")
game_deck = Deck()
game_deck.shuffle()
for i in range(int(len(game_deck.all_cards)/2)):
    player1.add_card(game_deck.deal_one())
    player2.add_card(game_deck.deal_one())
    
game_on = True
round_num = 0
while game_on:
    round_num += 1
    print(f'Round {round_num}, fight!')
    
    player1_played_cards = []
    player1_played_cards.append(player1.remove_one())
    player2_played_cards = []
    player2_played_cards.append(player2.remove_one())
    
    at_war = True
    while at_war:
        if player1_played_cards[-1].value > player2_played_cards[-1].value:
            player1.add_card(player1_played_cards)
            player1.add_card(player2_played_cards)
            at_war = False
        elif player2_played_cards[-1].value > player1_played_cards[-1].value:
            player2.add_card(player2_played_cards)
            player2.add_card(player1_played_cards)
            at_war = False
        else:
            print('War!')
            if len(player1.hand) < cards_for_war:
                print(f'Player {player1.name} unable to play war! Player {player2.name} Wins!')
                at_war = False
                game_on = False
            elif len(player2.hand) < cards_for_war:
                print(f'Player {player2.name} unable to play war! Player {player1.name} Wins!')
                at_war = False
                game_on = False
            else:
                for num in range(cards_for_war):
                    player1_played_cards.append(player1.remove_one())
                    player2_played_cards.append(player2.remove_one())
    
    if len(player1.hand) == 0:
        print(f'Player {player1.name} out of cards! Player {player2.name} wins!')
        game_on = False
    elif len(player2.hand) == 0:
        print(f'Player {player2.name} out of cards! Player {player1.name} wins!')
        game_on = False
# Out:
# Round 1, fight!
# Round 2, fight!
# Round 3, fight!
# Round 4, fight!
# Round 5, fight!
# Round 6, fight!
# Round 7, fight!
# Round 8, fight!
# Round 9, fight!
# Round 10, fight!
# Round 11, fight!
# Round 12, fight!
# Round 13, fight!
# Round 14, fight!
# Round 15, fight!
# Round 16, fight!
# Round 17, fight!
# Round 18, fight!
# Round 19, fight!
# Round 20, fight!
# Round 21, fight!
# Round 22, fight!
# Round 23, fight!
# Round 24, fight!
# Round 25, fight!
# Round 26, fight!
# Round 27, fight!
# Round 28, fight!
# Round 29, fight!
# Round 30, fight!
# Round 31, fight!
# Round 32, fight!
# Round 33, fight!
# Round 34, fight!
# Round 35, fight!
# Round 36, fight!
# Round 37, fight!
# Round 38, fight!
# Round 39, fight!
# Round 40, fight!
# Round 41, fight!
# Round 42, fight!
# Round 43, fight!
# Round 44, fight!
# Round 45, fight!
# Round 46, fight!
# Round 47, fight!
# Round 48, fight!
# Round 49, fight!
# Round 50, fight!
# Round 51, fight!
# War!
# Round 52, fight!
# ...

# %%
# Out:
# Four of Diamonds
